# %% [markdown]
# ## Result of optuna hyperparameters search using SLIM Elastic Net Model
#
# The followings are the search spaces used for the hyperparameters:
# - topK: 0-999
# - l1_ratio: 1e-4 - 0.1
# - alpha: 1e-3 - 0.01
#
# We run 26 training processes in parallel, each one with 20 (or more) iterations, using kaggle and colab notebooks

# %% [markdown]
# | Output | l1_ratio | alpha | topK | MyMAP | LeaderboardMap |
# | --- | --- | --- | --- | --- | --- |
# | 1 | 0.06390431044861844 | 0.0012467837064193649 | 290 | 0.05100 | 0.13755 |
# | 2 | 0.060154846519505714 | 0.0011476239425616567 | 567 | 0.05127 | ? |
# | 3 | 0.01616296440325903 | 0.0015096710293557303 | 374 | 0.05146 | 0.13767 |
# | 4 | 0.07016781280628812 | 0.001144027284096978 | 328 | 0.05120 | ? |
# | 5 | 0.0331318722514773 | 0.0011194608829797796 | 333 | 0.05160 | 0.13835 |
# | 6 | 0.09138431873925557 | 0.0010317646770670785 | 662 | 0.05150 | ? |
# | 7 | 0.06275007329588374 | 0.0012189575530384754 | 533 | 0.05139 | ? |
# | 8 | 0.0936115443099144 | 0.001110174602132339 | 278 | 0.05127 | 0.13756 |
# | 9 | 0.06417452404100085 | 0.0012824983456976137 | 412 | 0.05158 | 0.13805 |
# | 10 | 0.09619497009675372 | 0.0011442989973328808 | 553 | 0.05145 | 0.13710 |
# | 11 | 0.02310373797780513 | 0.0024735919201625163 | 216 | 0.05129 | ? |
# | 12 | 0.013956443309067522 | 0.002790292117499249 | 135 | 0.05128 | ? |
# | 13 | 0.055405966383473934 | 0.0010707296792354533 | 717 | 0.05143 | ? |
# |  |  |  |  |  |  |

# %% [markdown]
# topK: 1-1500
# alpha: 0-1
# beta: 0-1
#
# | Output | alpha | beta | topK | MyMAP | LeaderboardMap |
# | --- | --- | --- | --- | --- | --- |
# | 1 | 0.5860907274132556 | 0.4229936237856761 | 573 | 0.05267 | 0.14042 |
# | 2 | 0.854804602503152 | 0.7681501717767809 | 1045 | 0.05260 | ? |
# | 3 | 0.6606630223766877 | 0.5130660259060851 | 898 | 0.05242 | ? |
# |  |  |  |  |  |  |
